# %%
from decoder import Decoder

# %%
my_decoder = Decoder()

# %%
my_decoder.load_models()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from PIL import Image

# %%
test_img = Image.open('D:/Datasets/messages/valid/images/00130.jpg')

# %%
display(test_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x1A4B92AE208>

# %%
enc_msg = my_decoder.read_encrypted_message(test_img)

# %%
enc_msg
# Out:
# 'XB41RV7ZID5RTV82'

# %%
my_decoder.decrypt_message(enc_msg)
# Out:
# 'QNEYGFWQJMHQMD J'
